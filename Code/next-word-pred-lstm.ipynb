# %% [markdown]
# # **Import**

# %%
import pickle
import numpy as np 
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense
from tensorflow.keras.preprocessing.sequence import pad_sequences
# Out:
# 2026-02-08 12:09:20.410939: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1770552560.620904      55 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1770552560.683495      55 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1770552561.205777      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1770552561.205822      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1770552561.205828      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1770552561.205833      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.

# %% [markdown]
# # **Load Pickel File**

# %%
with open("/kaggle/input/wiki-text-2-vocab/word_to_index.pkl", "rb") as file:
    word_to_index = pickle.load(file)
with open("/kaggle/input/wiki-text-2-vocab/index_to_word.pkl", "rb") as file:
    index_to_file = pickle.load(file)
with open("/kaggle/input/wiki-text-2-vocab/encoded_text.pkl", "rb") as file:
    encoded_text = pickle.load(file)

# %% [markdown]
# # **Sliding Window Implementation**

# %%
vocab_size = len(word_to_index) + 1 

def sliding_window_sequence_dataset(token_list, sequence_length):
    x = []
    y = []

    for i in range(sequence_length, len(token_list)):
        x.append(token_list[i - sequence_length : i])
        y.append(token_list[i])

    return np.array(x), np.array(y)

# %%
sequence_length = 20
x, y = sliding_window_sequence_dataset(encoded_text, sequence_length)
print(f"x shape : {x.shape}")
print(f"y shape : {y.shape}")
# Out:
# x shape : (2393391, 20)
# y shape : (2393391,)

# %% [markdown]
# # **LSTM**

# %%
x = x.astype("int32")
y = y.astype("int32")

model = Sequential([
    Embedding(input_dim = vocab_size, output_dim = 100),
    LSTM(150),
    Dense(vocab_size, activation="softmax")
])

# %%
model.compile(
    loss = "sparse_categorical_crossentropy",                                                                                                                                                        
    optimizer = "adam",
    metrics = ['accuracy'] 
)

model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_3 (Embedding)         │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_3 (LSTM)                   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # ***Training***

# %%
history = model.fit(
    x,
    y,
    epochs = 80,
    batch_size = 256,
    validation_split = 0.2
)
# Out:
# Epoch 1/80
# I0000 00:00:1770552657.654386     123 cuda_dnn.cc:529] Loaded cuDNN version 91002
# 7480/7480 ━━━━━━━━━━━━━━━━━━━━ 153s 20ms/step - accuracy: 0.1289 - loss: 6.5869 - val_accuracy: 0.1866 - val_loss: 6.0223
# Epoch 2/80
# 7480/7480 ━━━━━━━━━━━━━━━━━━━━ 150s 20ms/step - accuracy: 0.1980 - loss: 5.5774 - val_accuracy: 0.2028 - val_loss: 5.7690
# Epoch 3/80
# 7480/7480 ━━━━━━━━━━━━━━━━━━━━ 150s 20ms/step - accuracy: 0.2193 - loss: 5.1370 - val_accuracy: 0.2105 - val_loss: 5.6876
# Epoch 4/80
# 7480/7480 ━━━━━━━━━━━━━━━━━━━━ 150s 20ms/step - accuracy: 0.2357 - loss: 4.8471 - val_accuracy: 0.2148 - val_loss: 5.6749
# Epoch 5/80
# 7480/7480 ━━━━━━━━━━━━━━━━━━━━ 150s 20ms/step - accuracy: 0.2480 - loss: 4.6351 - val_accuracy: 0.2170 - val_loss: 5.7033
# Epoch 6/80
# 7480/7480 ━━━━━━━━━━━━━━━━━━━━ 150s 20ms/step - accuracy: 0.2586 - loss: 4.4664 - val_accuracy: 0.2174 - val_loss: 5.7410
# Epoch 7/80
# 7480/7480 ━━━━━━━━━━━━━━━━━━━━ 150s 20ms/step - accuracy: 0.2691 - loss: 4.3224 - val_accuracy: 0.2179 - val_loss: 5.7984
# Epoch 8/80
# 7480/7480 ━━━━━━━━━━━━━━━━━━━━ 150s 20ms/step - accuracy: 0.2780 - loss: 4.1999 - val_accuracy: 0.2172 - val_loss: 5.8580
# Epoch 9/80
# 7480/7480 ━━━━━━━━━━━━━━━━━━━━ 150s 20ms/step - accuracy: 0.2872 - loss: 4.0906 - val_accuracy: 0.2160 - val_loss: 5.9378
# Epoch 10/80
# 7480/7480 ━━━━━━━━━━━━━━━━━━━━ 150s 20ms/step - accuracy: 0.2945 - loss: 3.9976 - val_accuracy: 0.2147 - val_loss: 6.0163
# Epoch 11/80
# 7480/7480 ━━━━━━━━━━━━━━━━━━━━ 150s 20ms/step - accuracy: 0.3025 - loss: 3.9124 - val_accuracy: 0.2140 - val_loss: 6.0934
# Epoch 12/80
# 7480/7480 ━━━━━━━━━━━━━━━━━━━━ 150s 20ms/step - accuracy: 0.3102 - loss: 3.8402 - val_accuracy: 0.2113 - val_loss: 6.1743
# Epoch 13/80
# 7480/7480 ━━━━━━━━━━━━━━━━━━━━ 150s 20ms/step - accuracy: 0.3174 - loss: 3.7702 - val_accuracy: 0.2099 - val_loss: 6.2612
# Epoch 14/80
# 7480/7480 ━━━━━━━━━━━━━━━━━━━━ 150s 20ms/step - accuracy: 0.3241 - loss: 3.7088 - val_accuracy: 0.2095 - val_loss: 6.3397
# Epoch 15/80
# 7480/7480 ━━━━━━━━━━━━━━━━━━━━ 150s 20ms/step - accuracy: 0.3299 - loss: 3.6515 - val_accuracy: 0.2078 - val_loss: 6.4142
# Epoch 16/80
# 7480/7480 ━━━━━━━━━━━━━━━━━━━━ 150s 20ms/step - accuracy: 0.3358 - loss: 3.6038 - val_accuracy: 0.2042 - val_loss: 6.4887
# Epoch 17/80
# 7480/7480 ━━━━━━━━━━━━━━━━━━━━ 150s 20ms/step - accuracy: 0.3415 - loss: 3.5544 - val_accuracy: 0.2042 - val_loss: 6.5719
# Epoch 18/80
# 7480/7480 ━━━━━━━━━━━━━━━━━━━━ 150s 20ms/step - accuracy: 0.3459 - loss: 3.5176 - val_accuracy: 0.2022 - val_loss: 6.6481
# Epoch 19/80
# 7480/7480 ━━━━━━━━━━━━━━━━━━━━ 150s 20ms/step - accuracy: 0.3505 - loss: 3.4806 - val_accuracy: 0.2020 - val_loss: 6.7280
# Epoch 20/80
# 7480/7480 ━━━━━━━━━━━━━━━━━━━━ 150s 20ms/step - accuracy: 0.3556 - loss: 3.4406 - val_accuracy: 0.1984 - val_loss: 6.7965
# Epoch 21/80
# 7480/7480 ━━━━━━━━━━━━━━━━━━━━ 150s 20ms/step - accuracy: 0.3595 - loss: 3.4085 - val_accuracy: 0.1975 - val_loss: 6.8631
# Epoch 22/80
# 7480/7480 ━━━━━━━━━━━━━━━━━━━━ 150s 20ms/step - accuracy: 0.3642 - loss: 3.3754 - val_accuracy: 0.1968 - val_loss: 6.9354
# Epoch 23/80
# 7480/7480 ━━━━━━━━━━━━━━━━━━━━ 150s 20ms/step - accuracy: 0.3678 - loss: 3.3465 - val_accuracy: 0.1943 - val_loss: 7.0013
# Epoch 24/80
# 7480/7480 ━━━━━━━━━━━━━━━━━━━━ 150s 20ms/step - accuracy: 0.3711 - loss: 3.3210 - val_accuracy: 0.1938 - val_loss: 7.0768
# Epoch 25/80
# 7480/7480 ━━━━━━━━━━━━━━━━━━━━ 150s 20ms/step - accuracy: 0.3739 - loss: 3.2996 - val_accuracy: 0.1917 - val_loss: 7.1346
# Epoch 26/80
# 7480/7480 ━━━━━━━━━━━━━━━━━━━━ 150s 20ms/step - accuracy: 0.3768 - loss: 3.2739 - val_accuracy: 0.1907 - val_loss: 7.1844
# Epoch 27/80
# 7480/7480 ━━━━━━━━━━━━━━━━━━━━ 150s 20ms/step - accuracy: 0.3797 - loss: 3.2573 - val_accuracy: 0.1896 - val_loss: 7.2432
# Epoch 28/80
# 7480/7480 ━━━━━━━━━━━━━━━━━━━━ 150s 20ms/step - accuracy: 0.3826 - loss: 3.2321 - val_accuracy: 0.1885 - val_loss: 7.3016
# Epoch 29/80
# 7480/7480 ━━━━━━━━━━━━━━━━━━━━ 150s 20ms/step - accuracy: 0.3852 - loss: 3.2138 - val_accuracy: 0.1873 - val_loss: 7.3631
# Epoch 30/80
# 7480/7480 ━━━━━━━━━━━━━━━━━━━━ 150s 20ms/step - accuracy: 0.3871 - loss: 3.1971 - val_accuracy: 0.1866 - val_loss: 7.4259
# Epoch 31/80
# 7480/7480 ━━━━━━━━━━━━━━━━━━━━ 150s 20ms/step - accuracy: 0.3897 - loss: 3.1806 - val_accuracy: 0.1869 - val_loss: 7.4711
# Epoch 32/80
# 7480/7480 ━━━━━━━━━━━━━━━━━━━━ 150s 20ms/step - accuracy: 0.3920 - loss: 3.1620 - val_accuracy: 0.1849 - val_loss: 7.5177
# Epoch 33/80
# 7480/7480 ━━━━━━━━━━━━━━━━━━━━ 150s 20ms/step - accuracy: 0.3936 - loss: 3.1513 - val_accuracy: 0.1841 - val_loss: 7.5721
# Epoch 34/80
# 7480/7480 ━━━━━━━━━━━━━━━━━━━━ 150s 20ms/step - accuracy: 0.3950 - loss: 3.1363 - val_accuracy: 0.1835 - val_loss: 7.6153
# Epoch 35/80
# 7480/7480 ━━━━━━━━━━━━━━━━━━━━ 150s 20ms/step - accuracy: 0.3964 - loss: 3.1252 - val_accuracy: 0.1837 - val_loss: 7.6657
# Epoch 36/80
# 7480/7480 ━━━━━━━━━━━━━━━━━━━━ 150s 20ms/step - accuracy: 0.3990 - loss: 3.1095 - val_accuracy: 0.1818 - val_loss: 7.7118
# Epoch 37/80
# 7480/7480 ━━━━━━━━━━━━━━━━━━━━ 150s 20ms/step - accuracy: 0.3995 - loss: 3.1054 - val_accuracy: 0.1820 - val_loss: 7.7505
# Epoch 38/80
# 7480/7480 ━━━━━━━━━━━━━━━━━━━━ 150s 20ms/step - accuracy: 0.4019 - loss: 3.0881 - val_accuracy: 0.1819 - val_loss: 7.8009
# Epoch 39/80
# 7480/7480 ━━━━━━━━━━━━━━━━━━━━ 150s 20ms/step - accuracy: 0.4026 - loss: 3.0809 - val_accuracy: 0.1810 - val_loss: 7.8357
# Epoch 40/80
# 7480/7480 ━━━━━━━━━━━━━━━━━━━━ 150s 20ms/step - accuracy: 0.4044 - loss: 3.0689 - val_accuracy: 0.1794 - val_loss: 7.8784
# Epoch 41/80
# 7480/7480 ━━━━━━━━━━━━━━━━━━━━ 150s 20ms/step - accuracy: 0.4054 - loss: 3.0588 - val_accuracy: 0.1790 - val_loss: 7.9166
# Epoch 42/80
# 7480/7480 ━━━━━━━━━━━━━━━━━━━━ 150s 20ms/step - accuracy: 0.4063 - loss: 3.0517 - val_accuracy: 0.1787 - val_loss: 7.9626
# Epoch 43/80
# 7480/7480 ━━━━━━━━━━━━━━━━━━━━ 150s 20ms/step - accuracy: 0.4078 - loss: 3.0434 - val_accuracy: 0.1789 - val_loss: 7.9946
# Epoch 44/80
# 7480/7480 ━━━━━━━━━━━━━━━━━━━━ 150s 20ms/step - accuracy: 0.4093 - loss: 3.0340 - val_accuracy: 0.1784 - val_loss: 8.0283
# Epoch 45/80
# 7480/7480 ━━━━━━━━━━━━━━━━━━━━ 150s 20ms/step - accuracy: 0.4095 - loss: 3.0302 - val_accuracy: 0.1782 - val_loss: 8.0714
# Epoch 46/80
# 7480/7480 ━━━━━━━━━━━━━━━━━━━━ 150s 20ms/step - accuracy: 0.4102 - loss: 3.0203 - val_accuracy: 0.1763 - val_loss: 8.0967
# Epoch 47/80
# 7480/7480 ━━━━━━━━━━━━━━━━━━━━ 150s 20ms/step - accuracy: 0.4105 - loss: 3.0164 - val_accuracy: 0.1768 - val_loss: 8.1388
# Epoch 48/80
# 7480/7480 ━━━━━━━━━━━━━━━━━━━━ 150s 20ms/step - accuracy: 0.4122 - loss: 3.0085 - val_accuracy: 0.1764 - val_loss: 8.1702
# Epoch 49/80
# 7480/7480 ━━━━━━━━━━━━━━━━━━━━ 150s 20ms/step - accuracy: 0.4134 - loss: 3.0014 - val_accuracy: 0.1758 - val_loss: 8.1876
# Epoch 50/80
# 7480/7480 ━━━━━━━━━━━━━━━━━━━━ 150s 20ms/step - accuracy: 0.4137 - loss: 2.9939 - val_accuracy: 0.1757 - val_loss: 8.2275
# Epoch 51/80
# 7480/7480 ━━━━━━━━━━━━━━━━━━━━ 150s 20ms/step - accuracy: 0.4145 - loss: 2.9906 - val_accuracy: 0.1761 - val_loss: 8.2623
# Epoch 52/80
# 7480/7480 ━━━━━━━━━━━━━━━━━━━━ 150s 20ms/step - accuracy: 0.4148 - loss: 2.9876 - val_accuracy: 0.1746 - val_loss: 8.2953
# Epoch 53/80
# 7480/7480 ━━━━━━━━━━━━━━━━━━━━ 150s 20ms/step - accuracy: 0.4153 - loss: 2.9775 - val_accuracy: 0.1751 - val_loss: 8.3257
# Epoch 54/80
# 7480/7480 ━━━━━━━━━━━━━━━━━━━━ 150s 20ms/step - accuracy: 0.4163 - loss: 2.9764 - val_accuracy: 0.1747 - val_loss: 8.3627
# Epoch 55/80
# 7480/7480 ━━━━━━━━━━━━━━━━━━━━ 150s 20ms/step - accuracy: 0.4165 - loss: 2.9719 - val_accuracy: 0.1734 - val_loss: 8.3919
# Epoch 56/80
# 7480/7480 ━━━━━━━━━━━━━━━━━━━━ 150s 20ms/step - accuracy: 0.4174 - loss: 2.9638 - val_accuracy: 0.1735 - val_loss: 8.4131
# Epoch 57/80
# 7480/7480 ━━━━━━━━━━━━━━━━━━━━ 150s 20ms/step - accuracy: 0.4188 - loss: 2.9569 - val_accuracy: 0.1735 - val_loss: 8.4424
# Epoch 58/80
# 7480/7480 ━━━━━━━━━━━━━━━━━━━━ 150s 20ms/step - accuracy: 0.4199 - loss: 2.9500 - val_accuracy: 0.1741 - val_loss: 8.4739
# Epoch 59/80
# 7480/7480 ━━━━━━━━━━━━━━━━━━━━ 150s 20ms/step - accuracy: 0.4206 - loss: 2.9489 - val_accuracy: 0.1720 - val_loss: 8.4929
# Epoch 60/80
# 7480/7480 ━━━━━━━━━━━━━━━━━━━━ 150s 20ms/step - accuracy: 0.4190 - loss: 2.9474 - val_accuracy: 0.1718 - val_loss: 8.5194
# Epoch 61/80
# 7480/7480 ━━━━━━━━━━━━━━━━━━━━ 150s 20ms/step - accuracy: 0.4196 - loss: 2.9434 - val_accuracy: 0.1735 - val_loss: 8.5514
# Epoch 62/80
# 7480/7480 ━━━━━━━━━━━━━━━━━━━━ 150s 20ms/step - accuracy: 0.4217 - loss: 2.9365 - val_accuracy: 0.1729 - val_loss: 8.5789
# Epoch 63/80
# 7480/7480 ━━━━━━━━━━━━━━━━━━━━ 150s 20ms/step - accuracy: 0.4219 - loss: 2.9346 - val_accuracy: 0.1715 - val_loss: 8.5963
# Epoch 64/80
# 7480/7480 ━━━━━━━━━━━━━━━━━━━━ 150s 20ms/step - accuracy: 0.4219 - loss: 2.9320 - val_accuracy: 0.1723 - val_loss: 8.6260
# Epoch 65/80
# 7480/7480 ━━━━━━━━━━━━━━━━━━━━ 150s 20ms/step - accuracy: 0.4226 - loss: 2.9259 - val_accuracy: 0.1705 - val_loss: 8.6494
# Epoch 66/80
# 7480/7480 ━━━━━━━━━━━━━━━━━━━━ 150s 20ms/step - accuracy: 0.4231 - loss: 2.9232 - val_accuracy: 0.1712 - val_loss: 8.6670
# Epoch 67/80
# 7480/7480 ━━━━━━━━━━━━━━━━━━━━ 150s 20ms/step - accuracy: 0.4230 - loss: 2.9221 - val_accuracy: 0.1710 - val_loss: 8.6876
# Epoch 68/80
# 7480/7480 ━━━━━━━━━━━━━━━━━━━━ 150s 20ms/step - accuracy: 0.4234 - loss: 2.9194 - val_accuracy: 0.1712 - val_loss: 8.7158
# Epoch 69/80
# 7480/7480 ━━━━━━━━━━━━━━━━━━━━ 150s 20ms/step - accuracy: 0.4244 - loss: 2.9127 - val_accuracy: 0.1694 - val_loss: 8.7367
# Epoch 70/80
# 7480/7480 ━━━━━━━━━━━━━━━━━━━━ 150s 20ms/step - accuracy: 0.4247 - loss: 2.9087 - val_accuracy: 0.1709 - val_loss: 8.7644
# Epoch 71/80
# 7480/7480 ━━━━━━━━━━━━━━━━━━━━ 150s 20ms/step - accuracy: 0.4253 - loss: 2.9062 - val_accuracy: 0.1704 - val_loss: 8.7848
# Epoch 72/80
# 7480/7480 ━━━━━━━━━━━━━━━━━━━━ 150s 20ms/step - accuracy: 0.4254 - loss: 2.9038 - val_accuracy: 0.1689 - val_loss: 8.8067
# Epoch 73/80
# 7480/7480 ━━━━━━━━━━━━━━━━━━━━ 150s 20ms/step - accuracy: 0.4262 - loss: 2.8999 - val_accuracy: 0.1684 - val_loss: 8.8263
# Epoch 74/80
# 7480/7480 ━━━━━━━━━━━━━━━━━━━━ 150s 20ms/step - accuracy: 0.4263 - loss: 2.8972 - val_accuracy: 0.1696 - val_loss: 8.8549
# Epoch 75/80
# 7480/7480 ━━━━━━━━━━━━━━━━━━━━ 150s 20ms/step - accuracy: 0.4271 - loss: 2.8922 - val_accuracy: 0.1683 - val_loss: 8.8727
# Epoch 76/80
# 7480/7480 ━━━━━━━━━━━━━━━━━━━━ 151s 20ms/step - accuracy: 0.4271 - loss: 2.8901 - val_accuracy: 0.1688 - val_loss: 8.8948
# Epoch 77/80
# 7480/7480 ━━━━━━━━━━━━━━━━━━━━ 150s 20ms/step - accuracy: 0.4274 - loss: 2.8904 - val_accuracy: 0.1694 - val_loss: 8.9164
# Epoch 78/80
# 7480/7480 ━━━━━━━━━━━━━━━━━━━━ 150s 20ms/step - accuracy: 0.4277 - loss: 2.8848 - val_accuracy: 0.1688 - val_loss: 8.9401
# Epoch 79/80
# 7480/7480 ━━━━━━━━━━━━━━━━━━━━ 150s 20ms/step - accuracy: 0.4278 - loss: 2.8819 - val_accuracy: 0.1687 - val_loss: 8.9648
# Epoch 80/80
# 7480/7480 ━━━━━━━━━━━━━━━━━━━━ 150s 20ms/step - accuracy: 0.4288 - loss: 2.8781 - val_accuracy: 0.1682 - val_loss: 8.9590

# %%
model.save("word_pred_LSTM_model.keras")

# %% [markdown]
# # Evaluation

# %%
loss, accuracy = model.evaluate(x, y, batch_size=256)
print(f"Loss: {loss:.4f}")
print(f"Accuracy: {accuracy:.4f}")


##### Output #########
# 9350/9350 ━━━━━━━━━━━━━━━━━━━━ 1017s 109ms/step - accuracy: 0.4359 - loss: 2.9350
# Loss: 4.0218
# Accuracy: 0.3892
